# %%
import codecs
import glob
import logging
import os
import pprint
import re
import csv

# %%
import nltk
from subprocess import Popen, PIPE
from docx import Document
import pdfminer
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from io import StringIO
from __future__ import (
    absolute_import, division, print_function, unicode_literals
)

from docx import Document
from docx.document import Document as _Document
from docx.oxml.text.paragraph import CT_P
from docx.oxml.table import CT_Tbl
from docx.table import _Cell, Table
from docx.text.paragraph import Paragraph

# %%
from nltk.corpus import stopwords
from nltk.tag.stanford import StanfordPOSTagger

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
os.getcwd()
# Out:
# 'D:\\D drive\\DataAnalytics_StudyMaterial\\IIMB-BDA\\ProjectZ\\Iteration2'

# %%
os.chdir('D:\\D drive\\DataAnalytics_StudyMaterial\\IIMB-BDA\\ProjectZ\\Iteration2')

# %%
#Function to convert pdf to text
def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()
    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)
    fp.close()
    device.close()
    str1 = retstr.getvalue()
    retstr.close()
    return str1

# %%
#Read All Docx
def iter_block_items(parent):
    """
    Generate a reference to each paragraph and table child within *parent*,
    in document order. Each returned value is an instance of either Table or
    Paragraph. *parent* would most commonly be a reference to a main
    Document object, but also works for a _Cell object, which itself can
    contain paragraphs and tables.
    """
    if isinstance(parent, _Document):
        parent_elm = parent.element.body
        # print(parent_elm.xml)
    elif isinstance(parent, _Cell):
        parent_elm = parent._tc
    else:
        raise ValueError("something's not right")

    for child in parent_elm.iterchildren():
        if isinstance(child, CT_P):
            yield Paragraph(child, parent)
        elif isinstance(child, CT_Tbl):
            yield Table(child, parent)

# %%
#Function to convert doc formats (like .doc, .docx, .odt) to text
def document_to_text(filename, file_path):
    if filename[-4:] == ".doc":
        cmd = ['C:/antiword/antiword', file_path] #use antiword command
        p = Popen(cmd, stdout=PIPE)
        stdout, stderr = p.communicate()
        return stdout.decode('ascii', 'ignore')
    elif filename[-5:] == ".docx":
        doc = Document(file_path)
        fullText = []
        para_ix=0
        tbl_ix=0
        for block in iter_block_items(doc):
            block_type=block.__class__.__name__
            if block_type=='Table':
                for row in doc.tables[tbl_ix].rows:
                    for cell in row.cells:
                        for paracell in cell.paragraphs:
                            fullText.append(paracell.text)
                tbl_ix+=1
            elif block_type=='Paragraph':
                fullText.append(doc.paragraphs[para_ix].text)
                para_ix+=1
        return '\n'.join(fullText)
    elif filename[-4:] == ".odt":
        cmd = ['odt2txt', file_path]
        p = Popen(cmd, stdout=PIPE)
        stdout, stderr = p.communicate()
        return stdout.decode('ascii', 'ignore')
    elif filename[-4:] == ".pdf":
        return convert_pdf_to_txt(file_path)

# %%
resume_filenames = sorted(glob.glob(os.path.join('./IIM',"*.*")))

# %%
resume_filenames
# Out:
# ['./IIM\\AmitBats[6_0].doc',
#  './IIM\\BalakrishnaReddyS[4_6].docx',
#  './IIM\\CURRENT_022017_Santosh kumartoleti_Resume_f0fb3c53-c308-4f86-b335-b05ebd2cccc9_SantoshkumarToleti2_6.docx',
#  './IIM\\CURRENT_032017_BhaktiSubhash Naik_Resume_cf61cd93-ff05-4fc4-85ec-42301b5456f5_BhaktiSubhashNaik4_9.doc',
#  './IIM\\CURRENT_032017_Daljeet Singh DuggalDUGGAL_Resume_adb59f9d-a2e4-46b8-abdc-375b61107dc5_DaljeetSinghDuggal6_0.docx',
#  './IIM\\CURRENT_032017_DishantPatel_Resume_f88c74e3-8545-4156-a708-8d093885288e_DishantPatel6_0.docx',
#  './IIM\\CURRENT_032017_HIRALPARMAR_Resume_3e8d6f3d-2b01-4603-8a09-12a840772afc_hiral2_0.pdf',
#  './IIM\\CURRENT_032017_SHALINISHALINI K_Resume_e49f1c7b-d151-44b9-9afe-b774a6852495_SHALINIK2_7.docx',
#  './IIM\\CURRENT_032017_SandeeV S_Resume_2cd5e682-f1f0-4d95-9483-57a25f6965c0_SandeeVS4_3.doc',
#  './IIM\\CURRENT_032017_SnehlataKumari_Resume_2224bb2b-a3f9-4083-9d5d-5b0a158be3fc_SnehlataKumari2_8.doc',
#  './IIM\\CURRENT_032017_ravisankar_Resume_f243d558-3e41-4fa6-a67d-f324fb19b2d6_ravisankar4_5.doc',
#  './IIM\\CURRENT_032017_umashankar_Resume_77f65cee-4bce-4d83-9103-cc47c019eb96_umashankar11_0 (1).doc',
#  './IIM\\CURRENT_032017_yerramanenikoteswararao_Resume_560553c9-3c04-49c3-8702-a53b153ddb22_yerramanenikoteswararao5_2.docx',
#  './IIM\\CURRENT_042017_KARANVIRSINGH_Resume_24452b3d-e135-415d-b99e-a7c8a40d8891_KaranvirSingh2_2.docx',
#  './IIM\\CURRENT_042017_SAGARDEWAN_Resume_1161c5a0-f1f9-4c5e-a9d3-d79d1ebbc32d_SAGARDEWAN2_4.docx',
#  './IIM\\CURRENT_042017_SethuramKishore Ch_Resume_514570f0-3c55-4382-96f1-65f9a73bf119_Sethuram9_0.doc',
#  './IIM\\CURRENT_052017_ASHISHJAIN_Resume_02667350-11d5-471d-b3fd-a0c3d8c0d3e7_ASHISHJAIN2_6.docx',
#  './IIM\\CURRENT_052017_DeepanjanGhosh_Resume_ccd2dad2-b2cd-4ae9-95e4-859c0896fa8e_DeepanjanGhosh3_4.docx',
#  './IIM\\CURRENT_052017_DineshReddy_Resume_553992ad-15ce-45cb-844d-95afffa7ff4f_3_1.docx',
#  './IIM\\CURRENT_052017_HarikrishnaPalla_Resume_0b50617e-97f1-4b22-94c1-0fa51548daa2_harikrishnapalla5_0.doc',
#  './IIM\\CURRENT_052017_LaliteshUpadhyaya_Resume_9db2850b-a607-4a84-899d-1b0f9a0a8459_LaliteshUpadhyaya4_6.docx',
#  './IIM\\CURRENT_052017_NISHTHASHRIVASTAVA_Resume_c162f248-0fd9-4c0c-97b0-c22782d9cba1_NISHTHASHRIVASTAVA2_1.docx',
#  './IIM\\CURRENT_052017_PHANI TEJAYELLAPRAGADA VISAKHA_Resume_a72368b8-befc-4686-afdf-e2cf26735238_PhaniTeja3_5.docx',
#  './IIM\\CURRENT_052017_RagunathanAnnadurai_Resume_3a1aca2d-751e-45b8-8975-69a310116353_RagunathanAnnadurai3_6.docx',
#  './IIM\\CURRENT_052017_SAIKUMARKADA_Resume_a80bc2c6-71f8-4336-b4d9-7a8de2899966_KSaiKumar4_2.pdf',
#  './IIM\\CURRENT_052017_SaradhiPoluru_Resume_96f4e1db-a0b4-4d86-b78a-15737964766e_Saradhi3_3.docx',
#  './IIM\\CURRENT_052017_SaranSaran Kumar_Resume_3fa61230-f101-46b3-9cc4-b64192da89fd_SaranKumar4_0.doc',
#  './IIM\\CURRENT_052017_Shaikh ShadmaWarsi_Resume_af9ac017-9ce8-4e1b-b6c9-73d21feb820d_ShaikhShadmaWarsi3_3.docx',
#  './IIM\\CURRENT_052017_VIVEK KUMAR REDDYMUDUGANTI_Resume_f9d5afc7-1ddc-4702-9a6e-d6775cf9f68f_VivekReddy3_0.doc',
#  './IIM\\CURRENT_052017_YeshasMandya Devaraju_Resume_3fbd57d9-cd9e-4d75-bfad-38f1c526b427_YeshasMD4_3.docx',
#  './IIM\\CURRENT_052017_lakshmiprasad_Resume_1111a5b8-bac2-4e92-97f7-12ac4ea82ca4_lakshmiprasad4_0.doc',
#  './IIM\\CURRENT_052017_usharani_Resume_651d8412-2f0a-4908-a641-2c802d432158_Usha3_2.docx',
#  './IIM\\CURRENT_102016_PraphullaKumbhar_Resume_180a15b7-da2e-41d3-8238-28af8bd8000e_PraphullaKumbhar9_0.doc',
#  './IIM\\CURRENT_122016_BhagyashriKulkarni_Resume_7255583c-6e60-475a-ada2-4e9e2e64e159_BhagyashriKulkarni4_1.doc',
#  './IIM\\CURRENT_122016_ShikhaSelot_Resume_834060f4-f4c0-498b-9b20-f1da5911bb52_ShikhaSelot5_0.docx',
#  './IIM\\Ganesh[5_0].doc',
#  './IIM\\NagendraSwami[2_0].docx',
#  './IIM\\RajashekharaiahM[4_0].docx',
#  './IIM\\Rajesh[6_0].docx',
#  './IIM\\SWETA[2_11].pdf',
#  './IIM\\Shwetarathore[5_0].docx',
#  './IIM\\VNPoornimaDeviS[4_7].docx',
#  './IIM\\Venkatesh[4_1].doc',
#  './IIM\\~$RRENT_032017_Daljeet Singh DuggalDUGGAL_Resume_adb59f9d-a2e4-46b8-abdc-375b61107dc5_DaljeetSinghDuggal6_0.docx',
#  './IIM\\~$RRENT_032017_SnehlataKumari_Resume_2224bb2b-a3f9-4083-9d5d-5b0a158be3fc_SnehlataKumari2_8.doc',
#  './IIM\\~$nesh[5_0].doc']

# %%
corpus_raw = u""
for resumes in resume_filenames:
    print("Reading '{0}'...".format(resumes))
    corpus_raw+=document_to_text(resumes,os.path.join('./',resumes))
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# Reading './IIM\AmitBats[6_0].doc'...
# Corpus is now 14433 characters long
#
# Reading './IIM\BalakrishnaReddyS[4_6].docx'...
# Corpus is now 22915 characters long
#
# Reading './IIM\CURRENT_022017_Santosh kumartoleti_Resume_f0fb3c53-c308-4f86-b335-b05ebd2cccc9_SantoshkumarToleti2_6.docx'...
# Corpus is now 29530 characters long
#
# Reading './IIM\CURRENT_032017_BhaktiSubhash Naik_Resume_cf61cd93-ff05-4fc4-85ec-42301b5456f5_BhaktiSubhashNaik4_9.doc'...
# Corpus is now 33076 characters long
#
# Reading './IIM\CURRENT_032017_Daljeet Singh DuggalDUGGAL_Resume_adb59f9d-a2e4-46b8-abdc-375b61107dc5_DaljeetSinghDuggal6_0.docx'...
# Corpus is now 40681 characters long
#
# Reading './IIM\CURRENT_032017_DishantPatel_Resume_f88c74e3-8545-4156-a708-8d093885288e_DishantPatel6_0.docx'...
# Corpus is now 48486 characters long
#
# Reading './IIM\CURRENT_032017_HIRALPARMAR_Resume_3e8d6f3d-2b01-4603-8a09-12a840772afc_hiral2_0.pdf'...
# Corpus is now 51203 characters long
#
# Reading './IIM\CURRENT_032017_SHALINISHALINI K_Resume_e49f1c7b-d151-44b9-9afe-b774a6852495_SHALINIK2_7.docx'...
# Corpus is now 56762 characters long
#
# Reading './IIM\CURRENT_032017_SandeeV S_Resume_2cd5e682-f1f0-4d95-9483-57a25f6965c0_SandeeVS4_3.doc'...
# Corpus is now 75179 characters long
#
# Reading './IIM\CURRENT_032017_SnehlataKumari_Resume_2224bb2b-a3f9-4083-9d5d-5b0a158be3fc_SnehlataKumari2_8.doc'...
# Corpus is now 79593 characters long
#
# Reading './IIM\CURRENT_032017_ravisankar_Resume_f243d558-3e41-4fa6-a67d-f324fb19b2d6_ravisankar4_5.doc'...
# Corpus is now 89895 characters long
#
# Reading './IIM\CURRENT_032017_umashankar_Resume_77f65cee-4bce-4d83-9103-cc47c019eb96_umashankar11_0 (1).doc'...
# Corpus is now 98111 characters long
#
# Reading './IIM\CURRENT_032017_yerramanenikoteswararao_Resume_560553c9-3c04-49c3-8702-a53b153ddb22_yerramanenikoteswararao5_2.docx'...
# Corpus is now 106759 characters long
#
# Reading './IIM\CURRENT_042017_KARANVIRSINGH_Resume_24452b3d-e135-415d-b99e-a7c8a40d8891_KaranvirSingh2_2.docx'...
# Corpus is now 112009 characters long
#
# Reading './IIM\CURRENT_042017_SAGARDEWAN_Resume_1161c5a0-f1f9-4c5e-a9d3-d79d1ebbc32d_SAGARDEWAN2_4.docx'...
# Corpus is now 121290 characters long
#
# Reading './IIM\CURRENT_042017_SethuramKishore Ch_Resume_514570f0-3c55-4382-96f1-65f9a73bf119_Sethuram9_0.doc'...
# Corpus is now 126610 characters long
#
# Reading './IIM\CURRENT_052017_ASHISHJAIN_Resume_02667350-11d5-471d-b3fd-a0c3d8c0d3e7_ASHISHJAIN2_6.docx'...
# Corpus is now 131502 characters long
#
# Reading './IIM\CURRENT_052017_DeepanjanGhosh_Resume_ccd2dad2-b2cd-4ae9-95e4-859c0896fa8e_DeepanjanGhosh3_4.docx'...
# Corpus is now 137203 characters long
#
# Reading './IIM\CURRENT_052017_DineshReddy_Resume_553992ad-15ce-45cb-844d-95afffa7ff4f_3_1.docx'...
# Corpus is now 147832 characters long
#
# Reading './IIM\CURRENT_052017_HarikrishnaPalla_Resume_0b50617e-97f1-4b22-94c1-0fa51548daa2_harikrishnapalla5_0.doc'...
# Corpus is now 153954 characters long
#
# Reading './IIM\CURRENT_052017_LaliteshUpadhyaya_Resume_9db2850b-a607-4a84-899d-1b0f9a0a8459_LaliteshUpadhyaya4_6.docx'...
# Corpus is now 160044 characters long
#
# Reading './IIM\CURRENT_052017_NISHTHASHRIVASTAVA_Resume_c162f248-0fd9-4c0c-97b0-c22782d9cba1_NISHTHASHRIVASTAVA2_1.docx'...
# Corpus is now 164150 characters long
#
# Reading './IIM\CURRENT_052017_PHANI TEJAYELLAPRAGADA VISAKHA_Resume_a72368b8-befc-4686-afdf-e2cf26735238_PhaniTeja3_5.docx'...
# Corpus is now 166177 characters long
#
# Reading './IIM\CURRENT_052017_RagunathanAnnadurai_Resume_3a1aca2d-751e-45b8-8975-69a310116353_RagunathanAnnadurai3_6.docx'...
# Corpus is now 169460 characters long
#
# Reading './IIM\CURRENT_052017_SAIKUMARKADA_Resume_a80bc2c6-71f8-4336-b4d9-7a8de2899966_KSaiKumar4_2.pdf'...
# Corpus is now 174979 characters long
#
# Reading './IIM\CURRENT_052017_SaradhiPoluru_Resume_96f4e1db-a0b4-4d86-b78a-15737964766e_Saradhi3_3.docx'...
# Corpus is now 183156 characters long
#
# Reading './IIM\CURRENT_052017_SaranSaran Kumar_Resume_3fa61230-f101-46b3-9cc4-b64192da89fd_SaranKumar4_0.doc'...
# Corpus is now 193560 characters long
#
# Reading './IIM\CURRENT_052017_Shaikh ShadmaWarsi_Resume_af9ac017-9ce8-4e1b-b6c9-73d21feb820d_ShaikhShadmaWarsi3_3.docx'...
# Corpus is now 202990 characters long
#
# Reading './IIM\CURRENT_052017_VIVEK KUMAR REDDYMUDUGANTI_Resume_f9d5afc7-1ddc-4702-9a6e-d6775cf9f68f_VivekReddy3_0.doc'...
# Corpus is now 211701 characters long
#
# Reading './IIM\CURRENT_052017_YeshasMandya Devaraju_Resume_3fbd57d9-cd9e-4d75-bfad-38f1c526b427_YeshasMD4_3.docx'...
# Corpus is now 217166 characters long
#
# Reading './IIM\CURRENT_052017_lakshmiprasad_Resume_1111a5b8-bac2-4e92-97f7-12ac4ea82ca4_lakshmiprasad4_0.doc'...
# Corpus is now 225502 characters long
#
# Reading './IIM\CURRENT_052017_usharani_Resume_651d8412-2f0a-4908-a641-2c802d432158_Usha3_2.docx'...
# Corpus is now 229469 characters long
#
# Reading './IIM\CURRENT_102016_PraphullaKumbhar_Resume_180a15b7-da2e-41d3-8238-28af8bd8000e_PraphullaKumbhar9_0.doc'...
# Corpus is now 237963 characters long
#
# Reading './IIM\CURRENT_122016_BhagyashriKulkarni_Resume_7255583c-6e60-475a-ada2-4e9e2e64e159_BhagyashriKulkarni4_1.doc'...
# Corpus is now 247292 characters long
#
# Reading './IIM\CURRENT_122016_ShikhaSelot_Resume_834060f4-f4c0-498b-9b20-f1da5911bb52_ShikhaSelot5_0.docx'...
# Corpus is now 250876 characters long
#
# Reading './IIM\Ganesh[5_0].doc'...
# Corpus is now 257709 characters long
#
# Reading './IIM\NagendraSwami[2_0].docx'...
# Corpus is now 275075 characters long
#
# Reading './IIM\RajashekharaiahM[4_0].docx'...
# Corpus is now 285763 characters long
#
# Reading './IIM\Rajesh[6_0].docx'...
# Corpus is now 297018 characters long
#
# Reading './IIM\SWETA[2_11].pdf'...
# Corpus is now 301540 characters long
#
# Reading './IIM\Shwetarathore[5_0].docx'...
# Corpus is now 314331 characters long
#
# Reading './IIM\VNPoornimaDeviS[4_7].docx'...
# Corpus is now 321323 characters long
#
# Reading './IIM\Venkatesh[4_1].doc'...
# Corpus is now 327413 characters long
#
# Reading './IIM\~$RRENT_032017_Daljeet Singh DuggalDUGGAL_Resume_adb59f9d-a2e4-46b8-abdc-375b61107dc5_DaljeetSinghDuggal6_0.docx'...
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# <ipython-input-172-05c330dc8d43> in <module>()
#       2 for resumes in resume_filenames:
#       3     print("Reading '{0}'...".format(resumes))
# ----> 4     corpus_raw+=document_to_text(resumes,os.path.join('./',resumes))
#       5     print("Corpus is now {0} characters long".format(len(corpus_raw)))
#       6     print()
#
# <ipython-input-169-68c0f0a0c014> in document_to_text(filename, file_path)
#       7         return stdout.decode('ascii', 'ignore')
#       8     elif filename[-5:] == ".docx":
# ----> 9         doc = Document(file_path)
#      10         fullText = []
#      11         para_ix=0
#
# C:\ProgramData\Anaconda3\lib\site-packages\docx\api.py in Document(docx)
#      23     """
#      24     docx = _default_docx_path() if docx is None else docx
# ---> 25     document_part = Package.open(docx).main_document_part
#      26     if document_part.content_type != CT.WML_DOCUMENT_MAIN:
#      27         tmpl = "file '%s' is not a Word file, content type is '%s'"
#
# C:\ProgramData\Anaconda3\lib\site-packages\docx\opc\package.py in open(cls, pkg_file)
#     114         *pkg_file*.
#     115         """
# --> 116         pkg_reader = PackageReader.from_file(pkg_file)
#     117         package = cls()
#     118         Unmarshaller.unmarshal(pkg_reader, package, PartFactory)
#
# C:\ProgramData\Anaconda3\lib\site-packages\docx\opc\pkgreader.py in from_file(pkg_file)
#      30         Return a |PackageReader| instance loaded with contents of *pkg_file*.
#      31         """
# ---> 32         phys_reader = PhysPkgReader(pkg_file)
#      33         content_types = _ContentTypeMap.from_xml(phys_reader.content_types_xml)
#      34         pkg_srels = PackageReader._srels_for(phys_reader, PACKAGE_URI)
#
# C:\ProgramData\Anaconda3\lib\site-packages\docx\opc\phys_pkg.py in __new__(cls, pkg_file)
#      29             else:
#      30                 raise PackageNotFoundError(
# ---> 31                     "Package not found at '%s'" % pkg_file
#      32                 )
#      33         else:  # assume it's a stream and pass it to Zip reader to sort out
#
# PackageNotFoundError: Package not found at '././IIM\~$RRENT_032017_Daljeet Singh DuggalDUGGAL_Resume_adb59f9d-a2e4-46b8-abdc-375b61107dc5_DaljeetSinghDuggal6_0.docx'

# %%
corpus_raw
# Out:
# '\r\n\r\n|Professional Summary                                                      |\r\n|                                                                          |\r\n|Having 6 Years of Experience as a Software Developer in the IT industry.  |\r\n|Hands on experience in Java and J2EE (JDBC, Servlet, JSP).                |\r\n|Hands on experience in Spring Framework.                                  |\r\n|Hands on experience in Hibernate Framework.                               |\r\n|Hands on experience in Struts Framework.                                  |\r\n|Hands on experience in Tomcat, Eclipse.                                   |\r\n|Hands on experience in Design Pattern (GOF, J2EE).                        |\r\n|Hands on experience in SVN                                                |\r\n|Hands on experience in JUnit                                              |\r\n|Hands on experience in Maven,Log4J                                        |\r\n|Hands on experience in Web service(REST)                                  |\r\n|Hands on experience in Billing Platform                                   |\r\n|Good Knowledge in Facets                                                  |\r\n|Good Knowledge in Groovy                                                  |\r\n\r\n|Employment  Summary                                                       |\r\n|                                                                                                                                   |\r\n|Programmer Analyst, Cognizant Technology Solutions, Bangalore, India                                                               |\r\n|From Dec2014-Till Date                                                                                                             |\r\n|Software Engineer, Kellen Technology, Bangalore ,India  From Jan2011 -Nov2014                                                      |\r\n|Technical Skills                                                          |\r\n|                                                                                    |                                               |\r\n|Operating System:-Windows Family,                                                   |                                               |\r\n|Languages:-Java, HTML, Java Script,My Sql, Sql Server                               |                                               |\r\n|J2ee Technologies:-Servlet,JDBC,JSP                                                 |                                               |\r\n|Web Server:- Apache Tomcat                                                          |                                               |\r\n|Frameworks:-Spring,Hibernate,Struts                                                 |                                               |\r\n|Tools:-Eclipse,Maven                                                                |                                               |\r\n\r\n|Training                                                                  |\r\n\r\n    . HealthCare in Facets 5.1 Internal Training\r\n\r\n\r\n   |Education                                                                 |\r\n|                                                                          |\r\n|MCA, IGNOU, New Delhi in 2011, India                                      |\r\n|PGDCA,IGNOU,New Delhi in 2009,India                                       |\r\n|BCA ,IGNOU,New Delhi in 2006,India                                        |\r\n|                                                                          |\r\n\r\n|Project Experience - Cognizant Technology Solutions                       |\r\n\r\nProject #1:\r\n\r\nProject Name               : Clear Channel International\r\nClient                              :           CCI SmartBike\r\nTeam Size              :     14\r\nRole                   :     Team Member\r\nDuration               :           Feb 2016 to Till Date\r\nTechnology                   :  ...

# %% [markdown]
# ## POS Tagging with NLTK

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
raw_sentences[7]
# Out:
# '|\r\n|Hands on experience in SVN                                                |\r\n|Hands on experience in JUnit                                              |\r\n|Hands on experience in Maven,Log4J                                        |\r\n|Hands on experience in Web service(REST)                                  |\r\n|Hands on experience in Billing Platform                                   |\r\n|Good Knowledge in Facets                                                  |\r\n|Good Knowledge in Groovy                                                  |\r\n\r\n|Employment  Summary                                                       |\r\n|                                                                                                                                   |\r\n|Programmer Analyst, Cognizant Technology Solutions, Bangalore, India                                                               |\r\n|From Dec2014-Till Date                                                                                                             |\r\n|Software Engineer, Kellen Technology, Bangalore ,India  From Jan2011 -Nov2014                                                      |\r\n|Technical Skills                                                          |\r\n|                                                                                    |                                               |\r\n|Operating System:-Windows Family,                                                   |                                               |\r\n|Languages:-Java, HTML, Java Script,My Sql, Sql Server                               |                                               |\r\n|J2ee Technologies:-Servlet,JDBC,JSP                                                 |                                               |\r\n|Web Server:- Apache Tomcat                                                          |                                               |\r\n|Frameworks:-Spring,Hibernate,Struts                                                 |                                               |\r\n|Tools:-Eclipse,Maven                                                                |                                               |\r\n\r\n|Training                                                                  |\r\n\r\n    .'

# %%
st=nltk.sent_tokenize(corpus_raw)

# %%
wt=nltk.word_tokenize(corpus_raw)

# %%
print("No. Of Sentences = ",len(st))
print("No. of Word = ",len(wt))
# Out:
# No. Of Sentences =  2610
# No. of Word =  49833

# %%
#pt=nltk.pos_tag(re.sub("\|","",corpus_raw).split())
pt=[]
for sent_for_tag in st:
    #tokenized_text = nltk.word_tokenize(sent_for_tag)
    #read_pos=nltk.pos_tag(tokenized_text)
    read_pos=nltk.pos_tag(re.sub("\|","",sent_for_tag).split())
    EOS_exp=[".","."]
    read_pos.append(tuple(EOS_exp))
    read_pos.append(tuple("\n"))
    pt.append(read_pos)
    #pt.append(".,.")
    
    
#pt=nltk.pos_tag(raw_sentences[0].split())

# %%
len(pt[1])
# Out:
# 12

# %%
ctr=0
ix=0
for i in range(len(pt)):
    ctr+=len(pt[i])
print(ctr)
# Out:
# 47102

# %%
#pt=[]
#sent="The Quick Brown Fox Jumped Over the Lazy Dog."# Mary Had A little Lamb. Twinkle is a little star."
#raw_sentences = tokenizer.tokenize(sent)
#for sent_for_tag in raw_sentences:
    #tokenized_text = nltk.word_tokenize(sent_for_tag)
    #read_pos=nltk.pos_tag(tokenized_text)
    #read_pos=nltk.pos_tag(re.sub("\|","",sent_for_tag).split())
    #EOS_exp=[".","."]
    #read_pos.append(tuple(EOS_exp)) 
    #read_pos.append(tuple("\n"))
    #pt.append(read_pos)

# %%
type(exp)
tuple(exp)
# Out:
# ('.', '.')

# %% [markdown]
# ## POS Tagging with Stanford NLP

# %%
os.environ['JAVAHOME'] = "C:/Program Files/Java/jdk1.8.0_131/bin"
CLASSPATH = "D:/D drive/Installers/stanford-postagger-full-2016-10-31/stanford-postagger.jar"
STANFORD_MODELS =  "D:/D drive/Installers/stanford-postagger-full-2016-10-31/models"

# %%
st_pos = StanfordPOSTagger('D:/D drive/Installers/stanford-postagger-full-2016-10-31/models/english-left3words-distsim.tagger','D:/D drive/Installers/stanford-postagger-full-2016-10-31/stanford-postagger.jar')

# %%
sent="John has written SQL queries for a java based application."
st_pos.tag(sent.split())
# Out:
# [('John', 'NNP'),
#  ('has', 'VBZ'),
#  ('written', 'VBN'),
#  ('SQL', 'NNP'),
#  ('queries', 'NNS'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('java', 'NN'),
#  ('based', 'VBN'),
#  ('application.', 'IN')]

# %%
st_posTag=[]
for sent_for_tag in st:
    #tokenized_text = nltk.word_tokenize(sent_for_tag)
    #read_pos=nltk.pos_tag(tokenized_text)
    read_pos=st_pos.tag(re.sub("\|","",sent_for_tag).split())
    EOS_exp=[".","."]
    read_pos.append(tuple(EOS_exp))
    read_pos.append(tuple("\n"))
    st_posTag.append(read_pos)

#st_posTag=st_pos.tag(re.sub("\|","",corpus_raw).split())

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
st_pos.tag(tokenizer.tokenize('Having Around 4+ years of experience in Development and Implementation using JAVA/J2EE technologies'))
# Out:
# [('Having', 'VBG'),
#  ('Around', 'IN'),
#  ('4+', 'CD'),
#  ('years', 'NNS'),
#  ('of', 'IN'),
#  ('experience', 'NN'),
#  ('in', 'IN'),
#  ('Development', 'NNP'),
#  ('and', 'CC'),
#  ('Implementation', 'NNP'),
#  ('using', 'VBG'),
#  ('JAVA/J2EE', 'NN'),
#  ('technologies', 'NNS')]

# %%
with open('POS-CV_NLTKFull.csv','w',newline='',encoding='utf-8') as out:
    csv_out=csv.writer(out)
    csv_out.writerow(['Text','POS_Tag'])
    for row in range(len(pt)):
        for col in range(len(pt[row])):
            csv_out.writerow(pt[row][col])
